# %% [markdown]
# ## Intro
#
# **TODO 1. 카카오 채널 생성**
#
# 카카오 아이 오픈빌더를 사용하려면 우선 카카오 채널을 만들어야 합니다. [카카오톡 채널 for Business 사이트](https://business.kakao.com/info/kakaotalkchannel)에서 채널 관리자 가입을 해주세요. 가입이 완료되면 “새 카카오톡 채널 만들기" 버튼을 클릭하여 채널을 개설하시면 됩니다. 아래와 같은 스크린에서 채널 개설을 위해 필요한 정보를 입력해주세요. 이때 **채널 관리자 센터 대시보드의 프로필 설정에서 홈 공개를 ON으로** 해주시는 것 잊지마세요!
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **TODO 2. 카카오 아이 오픈빌더 OBT(Open Beta Test) 신청**
#
# [카카오 아이 디벨로퍼스 사이트](https://i.kakao.com)에서 OBT 참여 신청을 해주세요. 아래와 같은 스크린에서 방금 생성한 카카오 채널 홈 URL을 비롯하여 필요한 정보를 입력하시면 됩니다. OBT 신청 심사는 보통 6일 이내로 완료되며 심사 결과는 이메일로 전송됩니다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **TODO3. 봇 생성**
#
# OBT 참여 승인을 받았다면 카카오 아이 디벨로퍼스 회원 가입을 하여 오픈빌더를 사용할 수 있습니다. “+”을 클릭, “카카오톳 챗봇” 버튼을 클릭한 후, 봇 이름을 입력합니다.
#
# **TODO4. 봇과 채널 연결**
#
# 마지막으로 앞에서 개설한 채널과 방금 생성한 봇을 연결해야 합니다. 설정 탭으로 이동 후 운영 채널 연결에서 본인이 개설한 채널을 선택합니다.

# %% [markdown]
# ---
#
# # 10.2 카카오톡 챗봇 연동
#
# 지금까지 잘 따라왔다면 카카오톡 챗봇을 만들기 위한 기본 준비는 마친 겁니다. 이제 우리가 만든 챗봇 엔진을 연결하기 위해 필요한 몇 가지 주요 개념을 알아봅시다! 오픈빌더만을 이용해 챗봇을 제작한다면 조금 더 다양한 개념과 사용법을 익혀야 하지만 카카오톡 챗봇 연동에 필요한 두 가지 개념만 알아보겠습니다.
#
# ## 10.2.1 시나리오와 블록
#
# 오픈빌더에서는 **사용자 의도 intent를 처리하는 가장 작은 단위**를 **‘블록(block)’**이라고 합니다. **이 블
# 록들이 모여서 하나의 ‘시나리오(scenario)’**로 구성됩니다. 이렇게 카카오톡 챗봇은 시나리오를 어떻게 구성하느냐에 따라 챗봇의 기능이 달라집니다. 블록에는 사용자 예상 발화 패턴이나 봇이 수행하는 액션과 응답 형식을 정의합니다. 즉, 사용자 발화가 입력되었을 때 블록 내 발화 패턴을 기반으로 사용자 의도가 파악되어 최종적으로 1개의 블록이 실행됩니다. 예를 들어 음식 주문이나 위치 안내 같이 챗봇이 처리해야 할 기능 단위로 블록이 만들어집니다.
#
# <블록 작동 원리>
# ![image.png](data:image/png;base64,...)
#
# 오픈빌더에서 생성된 모든 봇은 기본 시나리오를 포함합니다. 사용자는 설계하는 봇에 따라 시나리오와 블록을 추가할 수 있습니다. 이 책에서는 사용자 발화 처리를 우리가 제작한 챗봇 엔진에서 직접 하기 때문에 시나리오를 추가하는 방법은 다루지 않습니다. 기본 시나리오에는 다음 그림처럼 3가지 기본 제공 블록이 존재합니다.
#
# ![image.png](data:image/png;base64,...)![Untitled](https://s3-us-west-2.amazonaws.com/secure.notion-static.com/d1940519-f5ad-46c0-949e-f9f44e5eabc5/Untitled.png)
#
# - 웰컴 블록 : 사용자가 카카오톡 채널 방에 최초로 입장했을 때 발송하는 웰컴 메시지를 정의할 수 있습니다. 웰컴블록은 최초 1회만 작동합니다.
# - 폴백 블록 : 챗봇이 사용자의 발화 의도를 이해하지 못할 때의 동작을 정의할 수 있습니다. 일반적으로 '이해를 잘 못했어요'와 같은 메시지를 정의합니다.
# - 탈출 블록 : 챗봇이 사용자에게 계속해서 되묻는 상황에서 탈출하고 싶을 때 사용자 명령어를 정의합니다. 우리는 사용자의 발화를 우리가 만든 엔진에서 처리하기 때문에 탈출 블록은 사용하지 않습니다.

# %% [markdown]
# ## 10.2.2 스킬
#
# 스킬 Skill 은 외부에서 구현한 기능을 호출해 사용자에게 정보를 출력해주는 기능입니다.  스킬은 블록의 출력 기능과 비슷하지만 응답 설정을 프로그램으로 처리할 수 있는 장점이 있습니다. 즉, 외부에서 만든 기능을 카카오톡 챗봇에 맞게 응답을 출력할 수 있습니다.
#
# 스킬도 해당 블록의 발화에 반응하여 응답을 돌려주므로 스킬과 블록을 연결하는 과정이 필요합니다. 다음은 사용자 발화가 입력되었을 때 스킬을 처리하는 과정을 보여주는 그림입니다. 음식 주문 관련 발화를 처리할 수 있는 주문 블록이 존재하고 이때 주문 정보를 DB 서버에 저장하고 처리할 수 있는 스킬 서버가 있어야합니다. 다음 그림처럼 음식 주문 요청 발화가 봇에 입력되면 주문 블록에 연결된 스킬을 호출하게 됩니다. 이후 스킬 서버에서는 주문 정보를 DB에 저장하고 주문 처리 결과를 스킬 응답 포맷에 맞게 반환하면 봇에서는 스킬 서버의 응답에 맞게 사용자에게 답변합니다.
#
# <스킬 처리 과정>
# ![image.png](data:image/png;base64,...)
#
# 어떻게 우리가 만든 챗봇 엔진을 카카오톡 챗봇에 연결할 수 있을까요?
#
# 공식적으로 오픈빌더는 외부 챗봇 엔진을 지원하지 않습니다. 하지만 사용자 발화 의도를 이해하지 못했을 때 대응할 수 있는 폴백 블록 fill-back block 을 지원합니다. 폴백 블록은 사용자 발화를 처리할 수 있는 시나리오 블록이 더 이상 없을 때 실행됩니다.
#
# 우리는 모든 사용자 발화를 폴백 블록에서 처리하도록 기본 블록 이외에 다른 시나리오 블록은 생성하지 않습니다. 그다음 폴백 블록에서 챗봇 API 서버와 통신할 수 있는 스킬을 지정한다면 외부 챗봇 엔진을 사용할 수 있습니다.
#
# 다음 그림은 오픈빌더에서 외부 챗봇 엔진과 연동하는 방법을 보여주고 있습니다. 그림처럼 다양한 시나리오 블록이 존재한다면 발화 주제에 따라 카카오 챗봇 엔진과 우리가 제작한 챗봇 엔진을 같이 사용할 수 있습니다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 10.3 스킬 사용하기
# 카카오톡 챗봇을 우리가 제작한 챗봇 엔진에 연동하기 위해서는 스킬 사용이 필수적이며 따라서 기본적인 스킬을 만들어보는 시간을 가져봅시다! 스킬을 사용하기 스킬 서버가 필요합니다. 이를 위해 [지난 6편](https://dacon.io/competitions/official/235946/codeshare/6018)에서 다뤄보았던 파이썬 Flask를 이용해봅시다.
#
# ### 10.3.1 스킬 서버 이해하기
#
# 스킬 서버는 카카오 봇 시스템에서 받은 요청을 처리해 적절한 응답을 반환해줍니다. 이때 각각의 요청은 **HTTP POST 메서드를 통해 전달되고 JSON 형태**로 데이터를 주고 받습니다. (지난 6편에서 배운 REST API 서버를 만드는 방식과 동일합니다.)
#
# ![image.png](data:image/png;base64,...)
#
# *** HTTP POST 스킬 요청 (봇 시스템 → 스킬 서버)**
#
# POST 요청에는 스킬 페이로드(payload)를 포함합니다. 스킬 페이로드란 **봇 시스템이 스킬 서버에 Body로 전달하는 JSON 형태의 요청 데이터**로, 주로 스킬 서버에서 처리해야 하는 정보(사용자 정보, 발화, 블록 등)가 포함됩니다.
#
# *** HTTP  스킬 응답 (스킬 서버 → 봇 시스템)**
#
# 스킬 서버 응답(response)은 **스킬 서버가 봇 시스템에 전달하는 응답**으로, 주로 봇 시스템이 사용자에게 출력해야 하는 정보가 포함됩니다. (템플릿, 데이터)
#
# ### 10.3.2 스킬 서버 만들기
#
# 2가지 REST API를 제공하는 간단한 스킬 서버를 만들어봅시다. 스킬 서버에서 제공하는 2가지 API URI는 다음과 같습니다.
#
# 1. ‘안녕'이라는 텍스트를 봇 시스템에 텍스트형 응답으로 반환하는 스킬
#
# ```
# * 단순 텍스트형 응답 스킬
# POST /api/sayHello
# ```
#
#
# 2. ‘안녕'이라는 텍스트를 봇 시스템에 텍스트형 응답으로 반환하는 스킬
#
# ```
# * 단순 이미지형 응답 스킬
# POST /api/showHello
# ```
#
# <br>
#
# 아래 코드는 파이썬 Flask로 만든 간단한 스킬 서버입니다. /hello_kakao_skill 디렉터리를 만들고 app.py 파일을 생성합니다.

# %%
from flask import Flask, request
app = Flask(__name__)

# 카카오톡 텍스트형 응답
@app.route('/api/sayHello', methods=['POST'])
def sayHello():
    body = request.get_json()
    print(body)
    print(body['userRequest']['utterance'])

    responseBody = {
        "version": "2.0",
        "template": {
            "outputs": [
                {
                    "simpleText": {
                        "text": "안녕 hello I'm Ryan"
                    }
                }
            ]
        }
    }

    return responseBody

# %% [markdown]
# 단순 텍스트형 응답을 반환하는 REST API(/api/sayHello)입니다.
#
# ‘/api/sayHello’ 라우팅을 담당하는 sayHello() 함수는 카카오 봇 시트템의 요청 body(스킬 페이로드)를 확인하기 위해 로그를 출력한 후 단순 텍스트형 응답(simpleText)을 responseBody에 저장된 JSON 포맷으로 카카오 봇 시스템에 반환하고, 이후 카카오톡 채팅창 화면에 ‘hello I’m Ryan’ 텍스트가 담긴 말풍선이 출력됩니다.

# %%
# 카카오톡 이미지형 응답
@app.route('/api/showHello', methods=['POST'])
def showHello():
    body = request.get_json()
    print(body)
    print(body['userRequest']['utterance'])

    responseBody = {
        "version": "2.0",
        "template": {
            "outputs": [
                {
                    "simpleImage": {
                        "imageUrl": "https://t1.daumcdn.net/friends/prod/category/M001_friends_ryan2.jpg",
                        "altText": "hello I'm Ryan"
                    }
                }
            ]
        }
    }

    return responseBody


if __name__ == '__main__':
    app.run(host='0.0.0.0', port=5000)

# %% [markdown]
# 단순 이미지형 응답을 반환하는 REST API (/api/showHello)입니다.
#
# ‘/api/showHello’ 라우팅을 담당하는 showHello() 함수는 카카오 봇 시트템의 요청 body(스킬 페이로드)를 확인하기 위해 로그를 출력한 후 단순 이미지형 응답(simpleImage)을 responseBody에 저장된 JSON 포맷으로 카카오 봇 시스템에 반환하고, 이후 카카오톡 채팅창 화면에 손 흔드는 라이언 이미지가 담긴 말풍선이 출력됩니다.
#
# 이 절에서 사용한 예제는 카카오 아이 오픈빌더 도움말에서 node.js용으로 제공된 기본 예제를 파이썬 Flask에 맞게 수정한 것이며, 라이언 이미지 역시 오픈빌더 도움말의 기본 예제에서 사용한 이미지를 그대로 사용했습니다.
#
# (예제 확인 > i.kakao.com/docs/skill-build)

# %% [markdown]
# ## 10.3.3 오픈빌더에서 스킬/블록 등록하기
#
# 위에 과정을 완료한 후에는 다시 웹사이트로 돌아와서 2가지 기능을 할 수 있는 스킬을 등록해보도록 하겠습니다.
#
# ![image.png](data:image/png;base64,...)
#
# 다음 그림에서 생성 버튼을 눌러줍니다.
# ![image.png](data:image/png;base64,...)
#
# 제목과 설명, URL을 입력해줍니다. 이때 URL은 본인이 구축한 스킬 API 서버 주소를 입력해야합니다. 동일한 방법으로 이미지 응답 스킬도 만들어주세요.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 이전 화면으로 돌아가면 위와 같이 등록된 스킬 정보를 확인할 수 있습니다. 이제, 시나리오를 등록해주겠습니다.
#
# ![image.png](data:image/png;base64,...)
#
# 시나리오 탭으로 이동하여 +시나리오 버튼을 눌러주세요.
#
# ![image.png](data:image/png;base64,...)
#
# 블록 이름에 ‘단순 텍스트’를, 사용자 발화에는 사용자 입력으로 예상하는 질문을 등록해주세요.
#
# ![image.png](data:image/png;base64,...)
#
# 사용자 발화 등록을 완료한 후에는 파라미터 설정 영역에서 ‘스킬 선택' 선택 박스를 선택하면 나오는 텍스트 응답 스킬을 클릭해주세요.
#
# ![image.png](data:image/png;base64,...)
#
# 마지막으로 스킬 데이터를 선택해줍니다.
#
# 이와 같은 작업을 단순 이미지 블록도 생성해주세요. 이 때, 스킬은 이미지 응답 스킬로 선택하는 것을 주의해주세요.
#
# ![image.png](data:image/png;base64,...)
#
# 최종적으로 배포 과정을 거쳐야합니다. 배포 과정은 생략해도 되지만 이를 통해 변경 내용을 관리할 수 있음으로 해주는게 좋습니다.
#
# 마지막으로 스킬에 연결된 블록이 동작하는지 카카오톡 챗봇에서 확인해보겠습니다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 10.3.4 응답 타입별 JSON 포맷
#
# 스킬을 통해 카카오톡에서 봇 시스템의 요청과 응답을 하는 방법을 알아보겠습니다. 우선 봇 시스템이 스킬 API를 호출할 때 전달되는 스킬 페이로드(SkillPayload)를 알아봅시다. 10.1에서 만든 /api/sayHello 주소를 라우팅했던 함수 sayHello()에서 요청받은 스킬 페이로드 데이터를 출력한 결과를 살펴봅시다.

# %% [markdown]
# ```
# "bot": {
# 	"id": "<봇 아이디>",
# 	"name": "Irene"
# },
#
# "intent": {
# 	"id": "<블록 아이디>",
# 	"name": "단순 텍스트",
# 	"extra": {
# 		"reason": {
# 			"code": 1,
# 			"message": "OK"
# 		}
# 	}
# },
# "action": {
# 	"id": "<스킬 아이디>",
# 	"name": "단순 텍스트 응답 스킬",
# 	"params": {},
# 	"detailParams": {},
# 	"clientExtra": {}
# },
# ```
#
# 여기서 bot은 사용자 발화를 받은 봇의 정보를 담은 필드로 봇 아이디와 이름 정보가 들어있습니다. 다음으로 intent는 사용자 발화의 블록 정보를 답고 있는 필드이며 action은 실행되는 스킬 정보를 담고 있는 필드로 오픈빌더에서 스킬 호출 시 일반 파라미터를 추가하면 사용자 발화에서 추출한 개체 정보를 prams, detailParams, clientExtra 필드에 포함합니다.
#
# ```
# "userRequest": {
#     "block": {
#         "id": "<블록 아이디>",
#         "name": "단순 텍스트"
#     },
#     "user": {
#         "id": "<사용자 botUserKey>",
#         "type": "botUserKey",
#         "properties":{
#             "plusfriendUserKey": "<카카오 채널 사용자 id>"
#         }
#     },
#     "utterance": "안녕 텍스트",
#     "params": {},
#     "lang": "ko",
#     "timezone": "Asia/Seoul"
# },
# "contexts": []
# ```
#
# userRequest는 사용자 정보를 담고 있는 필드입니다. 스킬 페이로드에서 가장 중요한 정보를 담고 있으며 block은 사용자 발화가 인식된 블록 정보를, user는 챗봇 사용자 정보를 나타냅니다. <사용자 botUserKey>는 사용자를 식별하는데 사용되며 utterance는 봇 시스템에 전달된 사용자 발화입니다.
#
# ```
# {
# 	"version": "2.0",
# 	"template": {
# 		"outputs": [
# 			{
# 				"simpleText": {
# 					"text": "안녕하세요! Irene입니다."
# 				}
# 			}
# 		]
# 	}
# }
# ```
# 위에 스킬 응답에 대해 알아봅시다. 원래는 version, template, context, data 4 부분으로 구성되지만 꼭 필요한 것만을 알아보겠습니다. version은 스킬 응답의 버전을 나타내며 필수 요소입니다. template은 스킬 응답 출력 형태 정보를 담고 있는 필드입니다. 봇 시스템에서는 이를 스킬 템플릿(SkillTemplate)이라 부릅니다.
#
# 스킬템플릿에 대해 더 자세히 알아보겠습니다. 스킬에는 다양한 스킬템플릿이 제공되어 봇 응답 메세지에 따라 적절히 사용하면 됩니다. 스킬 템플릿의 outputs는 출력 그룹을 나타내며 텍스트, 음성, 주소, 카드형 등 다양한 출력 요소의 모습을 갖추고 있습니다.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 10.4 챗봇 API 서버에 카카오톡 연동
#
# 챗봇 API 서버에서 카카오톡 스킬을 처리할 수 있는 부분을 추가하겠습니다. 각 플랫폼에 따라 프로토콜을 부르는 명칭이 다르며, 카카오톡에서는 스킬이라 표현합니다.
#
# ##  10.4.1 챗봇 API 서버 수정
#
# 카카오 스킬 템플릿을 생성하는 모듈을 먼저 만들어줍니다. /chatbot_api 디렉터리 내에 KakaoTemplate.py 파일을 생성합니다.

# %%
class KakaoTemplate:
    def __init__(self):
        # 템플릿 버전
        self.version = "2.0"

    # 단순 텍스트 출력 요소
    def simpleTextComponent(self, text):
        return {
            "simpleText": {"text": text}
        }

    # 단순 이미지 출력 요소
    def simpleImageComponent(self, imageUrl, altText):
        return {
            "simpleImage": {"imageUrl": imageUrl, "altText": altText}
        }

    # 사용자에게 응답 스킬 전송
    def send_response(self, bot_resp):
        responseBody = {
            "version": self.version,
            "template": {
                "outputs": []
            }
        }

        # 이미지 답변이 텍스트 답변보다 먼저 출력 됨
        # 이미지 답변이 있는 경우
        if bot_resp['AnswerImageUrl'] is not None:
            responseBody['template']['outputs'].append(self.simpleImageComponent(bot_resp['AnswerImageUrl'], ''))

        # 텍스트 답변이 있는 경우
        if bot_resp['Answer'] is not None:
            responseBody['template']['outputs'].append(self.simpleTextComponent(bot_resp['Answer']))

        return responseBody

# %% [markdown]
# 기존의 /chatbot_api/app.py 코드에 카카오톡 스킬 처리 부분을 추가한 코드입니다.

# %%
from flask import Flask, request, jsonify, abort
import socket
import json

# 챗봇 엔진 서버 접속 정보
host = "127.0.0.1"  # 챗봇 엔진 서버 IP 주소
port = 5050  # 챗봇 엔진 서버 통신 포트

# Flask 어플리케이션
app = Flask(__name__)


# 챗봇 엔진 서버와 통신
def get_answer_from_engine(bottype, query):
    # 챗봇 엔진 서버 연결
    mySocket = socket.socket()
    mySocket.connect((host, port))

    # 챗봇 엔진 질의 요청
    json_data = {
        'Query': query,
        'BotType': bottype
    }
    message = json.dumps(json_data)
    mySocket.send(message.encode())

    # 챗봇 엔진 답변 출력
    data = mySocket.recv(2048).decode()
    ret_data = json.loads(data)

    # 챗봇 엔진 서버 연결 소켓 닫기
    mySocket.close()

    return ret_data


@app.route('/', methods=['GET'])
def index():
    return 'hello', 200


# 챗봇 엔진 query 전송 API
@app.route('/query/<bot_type>', methods=['POST'])
def query(bot_type):
    body = request.get_json()

    try:
        if bot_type == 'TEST':
            # 챗봇 API 테스트
            ret = get_answer_from_engine(bottype=bot_type, query=body['query'])
            return jsonify(ret)

        elif bot_type == "KAKAO":
            # 카카오톡 스킬 처리
            body = request.get_json()
            utterance = body['userRequest']['utterance']
            ret = get_answer_from_engine(bottype=bot_type, query=utterance)

            from KakaoTemplate import KakaoTemplate
            skillTemplate = KakaoTemplate()
            return skillTemplate.send_response(ret)

        elif bot_type == "NAVER":
            # 네이버톡톡 이벤트 처리
            pass

        else:
            # 정의되지 않은 bot type인 경우 404 오류
            abort(404)

    except Exception as ex:
        # 오류 발생시 500 오류
        abort(500)


if __name__ == '__main__':
    app.run(host='0.0.0.0', port=5000)

# %% [markdown]
# ## Outro
#
# 우리가 만든 챗봇 엔진과 연동에 필요한 오픈빌더 기본 개념과 사용법에 대해 알아보았습니다. 챗봇 엔진의 기본 원리를 파악하고 구현해보기 위한 것으로 오픈빌더에 대한 자세한 설명은 생략하였습니다. 오픈빌더 기능을 우리가 만든 챗봇 엔진의 기능과 학습 데이터셋을 더 보강한다면 더 수준 높은 챗봇을 만들 수 있을 것이라 생각합니다.
